# %% [markdown]
# # Day 5: Eval Baseline
#
# ## Goal
#
# Create a small reusable eval before trusting any tuning results.

# %% [markdown]
# ## Read Before Starting
#
# - lm-evaluation-harness repo overview
# - one or two evaluation-focused practical references
# - your own notes from the earlier days

# %%
eval_spec = {
    "task": "",
    "metric": "",
    "rubric": "",
    "eval_size": "",
}
eval_spec

# %% [markdown]
# ## Baseline Results
#
# - Total score:
# - Common errors:
# - Strong outputs:
# - Weak outputs:

# %% [markdown]
# ## Eval Limitations
#
# - What this eval captures well:
# - What it misses:
# - What might give misleading optimism:

# %% [markdown]
# ## X Post Draft
#
# Today I worked on evals before training.
#
# - Task:
# - Rubric:
# - Baseline result:
# - Failure example:
#
# It’s already obvious that a couple of good examples can hide weak overall behavior.
