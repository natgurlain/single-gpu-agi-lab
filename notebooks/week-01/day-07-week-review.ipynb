# %% [markdown]
# # Day 7: Week Review
#
# ## Goal
#
# Turn the first week into a clear next-step experiment and a public summary.

# %% [markdown]
# ## Review Inputs
#
# - Re-read your notes from Days 1 to 6
# - Revisit one model card and one paper summary
# - Look at your drafted X posts from the week

# %% [markdown]
# ## Week Summary
#
# - What I learned:
# - What I still do not understand:
# - Most promising tool:
# - Most realistic research direction:

# %% [markdown]
# ## Week 2 Experiment Brief
#
# - Experiment:
# - Why this next:
# - Inputs needed:
# - Success criteria:

# %% [markdown]
# ## Weekly Thread Draft
#
# This week I mapped the practical open-model stack from the perspective of one GPU.
#
# - I focused on inference, data, evals, and realistic QLoRA planning
# - I worked notebook-first so each step stayed visible
# - Biggest lesson:
# - Biggest misconception corrected:
# - Next experiment:
#
# I’m optimizing for practical reproduction, not vague AGI talk.
