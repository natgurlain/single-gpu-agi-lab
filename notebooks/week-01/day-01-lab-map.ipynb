# %% [markdown]
# # Day 1: Lab Map
#
# ## Goal
#
# Understand the modern open-model stack at a high level and define the working habits for this lab.

# %% [markdown]
# ## Learn Before Starting
#
# - Pretraining vs SFT vs DPO vs RL
# - Base model vs instruct model
# - Why single-GPU work should focus on post-training and evals
# - Basic terms: parameters, tokens, context length, quantization, VRAM, checkpoint, tokenizer

# %% [markdown]
# ## Read Before Starting
#
# - QLoRA paper: https://arxiv.org/abs/2305.14314
# - TRL docs: https://huggingface.co/docs/trl
# - vLLM quickstart: https://docs.vllm.ai/en/latest/getting_started/quickstart.html

# %%
# Fill in your machine details here
hardware = {
    "gpu": "",
    "vram_gb": "",
    "cpu": "",
    "ram_gb": "",
    "storage": "",
    "os": "",
}
hardware

# %% [markdown]
# ## Glossary
#
# Write short definitions in your own words.

# %% [markdown]
# ## Stack Map
#
# - Pretraining:
# - SFT:
# - DPO:
# - GRPO:
# - Inference:
# - Evals:

# %% [markdown]
# ## First Niche Statement
#
# `I reproduce practical single-GPU training and evaluation workflows for open models.`

# %% [markdown]
# ## X Post Draft
#
# I’m starting a single-GPU AI lab.
#
# Constraint: `[your GPU / VRAM]`
#
# Focus for the first phase:
# - local inference
# - evals
# - LoRA / QLoRA
# - small practical reproductions
#
# I’m using notebooks so every experiment is visible and repeatable.
#
# Next: map the stack clearly, then benchmark a few local models.
