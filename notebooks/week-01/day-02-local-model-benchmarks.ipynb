# %% [markdown]
# # Day 2: Local Model Benchmarks
#
# ## Goal
#
# Run a few open models locally and compare them on the same prompt set.

# %% [markdown]
# ## Read Before Starting
#
# - vLLM quickstart
# - bitsandbytes quantization docs
# - one model card for the model you are most likely to use

# %%
models = [
    {"name": "", "format": "", "notes": ""},
    {"name": "", "format": "", "notes": ""},
    {"name": "", "format": "", "notes": ""},
]
models

# %% [markdown]
# ## Prompt Set
#
# - 3 reasoning prompts
# - 3 coding prompts
# - 2 summarization prompts
# - 2 structured-output prompts

# %%
# Record your benchmark results here
results = []
results

# %% [markdown]
# ## Comparison Notes
#
# - Strongest overall:
# - Best value for hardware:
# - Best candidate for future tuning:
# - Biggest surprise:

# %% [markdown]
# ## X Post Draft
#
# Today I benchmarked 3 local open models on a single GPU.
#
# - Models: `[model 1]`, `[model 2]`, `[model 3]`
# - Best overall:
# - Best value:
# - Surprise:
#
# Next I’m moving from inference to data formatting and tokenization.
