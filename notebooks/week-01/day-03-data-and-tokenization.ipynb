# %% [markdown]
# # Day 3: Data And Tokenization
#
# ## Goal
#
# Define a narrow task and start understanding the data shapes behind it.

# %% [markdown]
# ## Read Before Starting
#
# - tokenizer summary docs
# - TRL dataset expectations
# - one instruction dataset page on Hugging Face

# %% [markdown]
# ## Task Definition
#
# What narrow task are you focusing on this week?

# %%
# Add a few starter examples here
dataset = [
    {"input": "", "output": ""},
]
dataset

# %% [markdown]
# ## Token Length Notes
#
# - Average prompt length:
# - Average completion length:
# - Longest example:
# - Formatting risks:

# %% [markdown]
# ## Data Risks
#
# - Inconsistent style
# - Mixed task definitions
# - Weak targets
# - Too-long outputs

# %% [markdown]
# ## X Post Draft
#
# Today I stopped thinking about training in the abstract and worked on data.
#
# - Task:
# - Data format:
# - Harder than expected:
# - Main lesson:
#
# Good data design already feels like part of model design.
