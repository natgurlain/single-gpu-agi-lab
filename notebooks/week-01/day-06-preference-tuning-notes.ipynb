# %% [markdown]
# # Day 6: Preference Tuning Notes
#
# ## Goal
#
# Build a practical mental model of SFT, DPO, and small RL-style tuning.

# %% [markdown]
# ## Read Before Starting
#
# - DPO paper
# - TRL DPO docs
# - TRL GRPO docs
# - Open-R1 overview

# %% [markdown]
# ## Plain-English Definitions
#
# - SFT:
# - DPO:
# - GRPO:

# %%
preference_example = {
    "prompt": "",
    "chosen": "",
    "rejected": "",
    "selection_rule": "",
}
preference_example

# %% [markdown]
# ## Decision
#
# - First real training step:
# - Why:
# - What would be misleading or fake:

# %% [markdown]
# ## X Post Draft
#
# Today I clarified something important for myself:
#
# - SFT teaches imitation
# - DPO teaches preference between responses
# - Heavy RL is not where I should start on one GPU
#
# Next: use this to choose a realistic training path instead of chasing hype.
