# %% [markdown]
# # Day 4: First QLoRA Plan
#
# ## Goal
#
# Turn the theory into a concrete first fine-tuning plan that fits one GPU.

# %% [markdown]
# ## Read Before Starting
#
# - QLoRA paper
# - PEFT docs
# - TRL docs
# - one implementation path: Unsloth or Axolotl

# %%
training_plan = {
    "model": "",
    "task": "",
    "dataset": "",
    "method": "QLoRA",
    "max_seq_length": "",
    "learning_rate": "",
    "batch_size": "",
    "gradient_accumulation": "",
}
training_plan

# %% [markdown]
# ## Experiment Matrix
#
# - Baseline untuned model
# - Run A:
# - Run B:
# - Single variable to change:

# %% [markdown]
# ## Success Criteria
#
# - Improvement target:
# - Eval method:
# - Failure modes to watch:

# %% [markdown]
# ## X Post Draft
#
# I mapped my first realistic QLoRA run for a single GPU.
#
# - Model:
# - Task:
# - Why QLoRA fits this hardware:
# - What I still need to validate:
#
# Next: define an eval I can trust before training.
