# %% [markdown]
# # Experiment Notebook
#
# Milestone:
#
# Project / paper:
#
# Decision target: integrate / archive / reject

# %% [markdown]
# ## Hypothesis
#
# Write the falsifiable claim this experiment tests.

# %% [markdown]
# ## Core Mechanism
#
# - Paper / source:
# - Mechanism in my own words:
# - Minimal implementation:

# %% [markdown]
# ## Baseline And Metric
#
# - Baseline:
# - Metric:
# - Success threshold:
# - Kill criterion:

# %%
# Setup cell
# Import libraries, print environment details, fix seeds, and define helpers here.

# %% [markdown]
# ## Config
#
# - Commit:
# - Hardware:
# - Seed:
# - Dataset / environment:
# - Checkpoint path:

# %%
# Main experiment cell

# %% [markdown]
# ## Results
#
# - Baseline result:
# - New result:
# - Raw logs / artifacts:
# - Failure examples:

# %% [markdown]
# ## Decision
#
# Decision: integrate / archive / reject
#
# Reason:
#
# Next experiment:

# %% [markdown]
# ## Public Artifact Draft
#
# I implemented `[paper/mechanism]` from scratch on one GPU.
#
# What worked:
# - ...
#
# What failed:
# - ...
#
# Metric:
# - baseline: ...
# - new method: ...
#
# Decision:
# - integrate / archive / reject
