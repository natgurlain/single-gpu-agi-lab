# %% [markdown]
# # Daily Lab Notebook
#
# ## Goal
#
# Write the goal for today in one or two sentences.

# %% [markdown]
# ## Learn Before Starting
#
# - Concept 1
# - Concept 2
# - Concept 3

# %% [markdown]
# ## Read Before Starting
#
# - Source 1
# - Source 2
# - Source 3

# %% [markdown]
# ## Pre-Flight Notes
#
# - What do I expect?
# - What would count as success?
# - What do I want to avoid?

# %%
# Setup cell
# Import libraries, print environment details, or define helper functions here.

# %% [markdown]
# ## Work Log
#
# Record what you tried, what changed, and what happened.

# %%
# Main experiment cell

# %% [markdown]
# ## Results
#
# - Main result:
# - Unexpected behavior:
# - Open questions:

# %% [markdown]
# ## X Post Draft
#
# Today in my single-GPU AI lab:
#
# - Focus:
# - Model / tool:
# - Main takeaway:
# - Surprise / failure:
#
# Next:
